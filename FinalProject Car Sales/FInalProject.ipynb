# %%
#Import libraries
import pandas as pd
import pymongo
import csv
import json
import numpy as np
import tensorflow as tf 
from tensorflow import keras

# %%
#define de variable for each csv 
expo="resources/Exportacion.csv"
hibridos="resources/Vehi_hibrido_electricos.csv"
ventas="resources/Ventas.csv"

# %%
#create the DF for each CSV
salesDF=pd.read_csv(ventas)
salesDF.head()
# Out:
#                             Tema   Año      Mes           Marca Modelo  \
# 0  Venta_al_publico_de_vehiculos  2005  Febrero  General_Motors    147
# 1  Venta_al_publico_de_vehiculos  2005    Marzo  General_Motors    147
# 2  Venta_al_publico_de_vehiculos  2005     Mayo  General_Motors    147
# 3  Venta_al_publico_de_vehiculos  2005    Enero  General_Motors    147
# 4  Venta_al_publico_de_vehiculos  2005    Abril  General_Motors    147
#
#           Tipo Segmento     Origen País origen  Total
# 0  Automoviles  De_Lujo  Importado      Italia     22
# 1  Automoviles  De_Lujo  Importado      Italia     12
# 2  Automoviles  De_Lujo  Importado      Italia     12
# 3  Automoviles  De_Lujo  Importado      Italia     11
# 4  Automoviles  De_Lujo  Importado      Italia     11

# %%
salesDF.rename(columns={"Tema":"TypeOfSale","Año":"Year","Marca":"Brand","Mes":"Month","Modelo":"Model","Segmento":"Segment","Origen":"Origin","Tipo":"CarType","País origen":"OriginCountry"},inplace=True)
salesDF.head()
# Out:
#                       TypeOfSale  Year    Month           Brand Model  \
# 0  Venta_al_publico_de_vehiculos  2005  Febrero  General_Motors   147
# 1  Venta_al_publico_de_vehiculos  2005    Marzo  General_Motors   147
# 2  Venta_al_publico_de_vehiculos  2005     Mayo  General_Motors   147
# 3  Venta_al_publico_de_vehiculos  2005    Enero  General_Motors   147
# 4  Venta_al_publico_de_vehiculos  2005    Abril  General_Motors   147
#
#        CarType  Segment     Origin OriginCountry  Total
# 0  Automoviles  De_Lujo  Importado        Italia     22
# 1  Automoviles  De_Lujo  Importado        Italia     12
# 2  Automoviles  De_Lujo  Importado        Italia     12
# 3  Automoviles  De_Lujo  Importado        Italia     11
# 4  Automoviles  De_Lujo  Importado        Italia     11

# %%
ExpoDF=pd.read_csv(expo)
#ExpoDF.head()

# %%
ExpoDF.rename(columns={"Tema":"TypeOfSale","Año":"Year","Marca":"Brand","Mes":"Month","Modelo":"Model","Segmento":"Segment","Tipo":"CarType","PaisDestino":"DestinationCountry"},inplace=True)
ExpoDF.head()
# Out:
#                  TypeOfSale  Year    Month  Brand         Model      CarType  \
# 0  Exportacion_de_vehiculos  2007  Octubre  Honda  Accord_4PTAS  Automoviles
# 1  Exportacion_de_vehiculos  2007  Octubre  Honda  Accord_4PTAS  Automoviles
# 2  Exportacion_de_vehiculos  2007  Octubre  Honda  Accord_4PTAS  Automoviles
# 3  Exportacion_de_vehiculos  2007    Julio  Honda  Accord_4PTAS  Automoviles
# 4  Exportacion_de_vehiculos  2007     Mayo  Honda  Accord_4PTAS  Automoviles
#
#    Segment DestinationCountry  Total
# 0  De_Lujo     Estados Unidos  -1966
# 1  De_Lujo             Brasil   -120
# 2  De_Lujo          Argentina    -48
# 3  De_Lujo            Uruguay      0
# 4  De_Lujo            Uruguay      1

# %%
#DF for Hybrid and electric cars in Mexico (INEGI information)
HybrDF=pd.read_csv(hibridos,encoding='latin-1')
#HybrDF.head()

# %%
HybrDF.rename(columns={"Tema":"TypeOfSale","Año":"Year","Mes":"Month","EntidadFederativa":"State","UnidadesVehicularesElectricas":"ElectricCars","UnidadesVehicularesHibridasPlugin1":"HybridPlugin1","UnidadesVehicularesHibridas2":"HybridPlugin2"},inplace=True)
HybrDF.head()
# Out:
#                                  TypeOfSale  Year       Month  \
# 0  Venta_de_vehiculos_hibridos_y_electricos  2019     Octubre
# 1  Venta_de_vehiculos_hibridos_y_electricos  2019       Junio
# 2  Venta_de_vehiculos_hibridos_y_electricos  2019  Septiembre
# 3  Venta_de_vehiculos_hibridos_y_electricos  2019       Julio
# 4  Venta_de_vehiculos_hibridos_y_electricos  2018   Diciembre
#
#               State  ElectricCars  HybridPlugin1  HybridPlugin2  Total
# 0  Ciudad_de_Mexico            15             66            933   1014
# 1  Ciudad_de_Mexico             5             18            804    827
# 2  Ciudad_de_Mexico            15             47            764    826
# 3  Ciudad_de_Mexico             7             26            716    749
# 4  Ciudad_de_Mexico             7             76            629    712

# %%
######## HYBRID'S SALES DATAFRAME BY YEAR #####################

HybByYear=HybrDF[["Year","TypeOfSale","State","ElectricCars","HybridPlugin1","HybridPlugin2","Total"]]

SaleByType=HybByYear.groupby(["Year","State"])
HybTotal=SaleByType["Total"].sum()
HybridByStateDF=pd.DataFrame({
    
    "Total_Sales":HybTotal
    
})
HybridByStateDF.reset_index(inplace=True)
HybridByStateDF.head(15)
# Out:
#     Year                 State  Total_Sales
# 0   2016        Aguascalientes           68
# 1   2016       Baja_California           54
# 2   2016   Baja_California Sur           32
# 3   2016              Campeche           14
# 4   2016               Chiapas           32
# 5   2016             Chihuahua           81
# 6   2016      Ciudad_de_Mexico         3838
# 7   2016  Coahuila_de_Zaragoza          101
# 8   2016                Colima           37
# 9   2016               Durango           52
# 10  2016            Guanajuato          185
# 11  2016              Guerrero           13
# 12  2016               Hidalgo          104
# 13  2016               Jalisco          624
# 14  2016                Mexico         1067

# %%
######## SALES DATAFRAME BY BRAND AND YEAR #####################
TotalbyYear=salesDF[["Year","Brand","Total"]]

SaleByBrand=TotalbyYear.groupby(["Year","Brand"])
BrandTotal=SaleByBrand["Total"].sum()
ByBrandDF=pd.DataFrame({
    
    "Total_Sales":BrandTotal
})
ByBrandDF.reset_index(inplace=True)

ByBrandDF.head(15)
# Out:
#     Year           Brand  Total_Sales
# 0   2005           Acura         1030
# 1   2005            Audi         3912
# 2   2005             BMW         6267
# 3   2005        Chrysler       124353
# 4   2005      Ford_Motor       190839
# 5   2005  General_Motors       249842
# 6   2005           Honda        38321
# 7   2005          Jaguar          416
# 8   2005      Land_Rover          716
# 9   2005         Lincoln         4311
# 10  2005        MG ROVER          311
# 11  2005           Mazda          771
# 12  2005   Mercedes_Benz         6953
# 13  2005            Mini         1902
# 14  2005      Mitsubishi        15004

# %%
conn="mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# %%
#create the database in Mongo
db = client['FinalProject']

# %%
for i in range(HybrDF.shape[0]):
    document = HybrDF.iloc[i].to_dict()
    document = {x:str(y) for x,y in document.items()}
    db.Hybrid.insert_one(document)

# %%
for i in range(ExpoDF.shape[0]):
    document2 = ExpoDF.iloc[i].to_dict()
    document2 = {x:str(y) for x,y in document2.items()}
    db.expo.insert_one(document2)

# %%
for i in range(salesDF.shape[0]):
    document3 = salesDF.iloc[i].to_dict()
    document3 = {x:str(y) for x,y in document3.items()}
    db.sales.insert_one(document3)

# %%
for i in range(HybridByStateDF.shape[0]):
    document4 = HybridByStateDF.iloc[i].to_dict()
    document4 = {x:str(y) for x,y in document4.items()}
    db.HybridFilter.insert_one(document4)

# %%
for i in range(ByBrandDF.shape[0]):
    document5 = ByBrandDF.iloc[i].to_dict()
    document5 = {x:str(y) for x,y in document5.items()}
    db.BrandFilter.insert_one(document5)

# %%
from flask import jsonify

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["FinalProject"]
mycol = mydb["BrandFilter"]

resultado = mycol.find({"Year":"2006"},{"_id":False})
resultado= [x for i,x in enumerate(resultado)]
resultado
# Out:
# [{'Year': '2006', 'Brand': 'Acura', 'Total_Sales': '1631'},
#  {'Year': '2006', 'Brand': 'Audi', 'Total_Sales': '4205'},
#  {'Year': '2006', 'Brand': 'BMW', 'Total_Sales': '7087'},
#  {'Year': '2006', 'Brand': 'Bentley', 'Total_Sales': '36'},
#  {'Year': '2006', 'Brand': 'Chrysler', 'Total_Sales': '128446'},
#  {'Year': '2006', 'Brand': 'Fiat', 'Total_Sales': '1040'},
#  {'Year': '2006', 'Brand': 'Ford_Motor', 'Total_Sales': '177595'},
#  {'Year': '2006', 'Brand': 'General_Motors', 'Total_Sales': '245090'},
#  {'Year': '2006', 'Brand': 'Honda', 'Total_Sales': '47471'},
#  {'Year': '2006', 'Brand': 'Jaguar', 'Total_Sales': '332'},
#  {'Year': '2006', 'Brand': 'Land_Rover', 'Total_Sales': '774'},
#  {'Year': '2006', 'Brand': 'Lincoln', 'Total_Sales': '5187'},
#  {'Year': '2006', 'Brand': 'Mazda', 'Total_Sales': '7495'},
#  {'Year': '2006', 'Brand': 'Mercedes_Benz', 'Total_Sales': '6452'},
#  {'Year': '2006', 'Brand': 'Mini', 'Total_Sales': '1806'},
#  {'Year': '2006', 'Brand': 'Mitsubishi', 'Total_Sales': '16751'},
#  {'Year': '2006', 'Brand': 'Nissan', 'Total_Sales': '228315'},
#  {'Year': '2006', 'Brand': 'Peugeot', 'Total_Sales': '16068'},
#  {'Year': '2006', 'Brand': 'Porsche', 'Total_Sales': '632'},
#  {'Year': '2006', 'Brand': 'Renault', 'Total_Sales': '20274'},
#  {'Year': '2006', 'Brand': 'SEAT', 'Total_Sales': '19899'},
#  {'Year': '2006', 'Brand': 'Smart', 'Total_Sales': '597'},
#  {'Year': '2006', 'Brand': 'Subaru', 'Total_Sales': '308'},
#  {'Year': '2006', 'Brand': 'Suzuki', 'Total_Sales': '4413'},
#  {'Year': '2006', 'Brand': 'Toyota', 'Total_Sales': '60088'},
#  {'Year': '2006', 'Brand': 'Volkswagen', 'Total_Sales': '135027'},
#  {'Year': '2006', 'Brand': 'Volvo', 'Total_Sales': '2717'}]

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["FinalProject"]
mycol = mydb["sales"]

resultado = mycol.find()
resultado= [x for i,x in enumerate(resultado)]
resultado
# Out:
# [{'_id': ObjectId('5e5dbcdc851d52ef14137ace'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Febrero',
#   'Brand': 'General_Motors',
#   'Model': '147',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '22'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137acf'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Marzo',
#   'Brand': 'General_Motors',
#   'Model': '147',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '12'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad0'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Mayo',
#   'Brand': 'General_Motors',
#   'Model': '147',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '12'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad1'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Enero',
#   'Brand': 'General_Motors',
#   'Model': '147',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '11'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad2'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Abril',
#   'Brand': 'General_Motors',
#   'Model': '147',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '11'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad3'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Agosto',
#   'Brand': 'General_Motors',
#   'Model': '147',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '5'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad4'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Junio',
#   'Brand': 'General_Motors',
#   'Model': '147',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '2'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad5'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Julio',
#   'Brand': 'General_Motors',
#   'Model': '147',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '1'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad6'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Febrero',
#   'Brand': 'General_Motors',
#   'Model': '156',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '14'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad7'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Enero',
#   'Brand': 'General_Motors',
#   'Model': '156',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '13'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad8'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Abril',
#   'Brand': 'General_Motors',
#   'Model': '156',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '11'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ad9'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Marzo',
#   'Brand': 'General_Motors',
#   'Model': '156',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '9'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ada'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Mayo',
#   'Brand': 'General_Motors',
#   'Model': '156',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '3'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137adb'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Julio',
#   'Brand': 'General_Motors',
#   'Model': '156',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '1'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137adc'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Diciembre',
#   'Brand': 'General_Motors',
#   'Model': '156',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Italia',
#   'Total': '1'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137add'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '259'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ade'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '223'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137adf'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '207'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae0'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '200'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae1'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '187'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae2'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '187'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae3'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '166'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae4'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '163'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae5'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '159'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae6'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '156'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae7'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '146'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae8'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '145'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137ae9'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '140'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137aea'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '137'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137aeb'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '136'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137aec'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '133'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137aed'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '130'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137aee'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '130'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137aef'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '127'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af0'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '125'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af1'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '125'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af2'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '123'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af3'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '114'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af4'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '108'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af5'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '107'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af6'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '106'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af7'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '104'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af8'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '102'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137af9'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '102'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137afa'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '101'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137afb'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '99'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137afc'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '97'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137afd'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '91'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137afe'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '89'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137aff'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '86'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b00'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '84'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b01'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '84'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b02'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '80'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b03'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '76'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b04'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '75'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b05'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '72'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b06'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '71'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b07'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '66'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b08'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '62'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b09'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '62'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b0a'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '59'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b0b'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '59'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b0c'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '58'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b0d'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '49'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b0e'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '49'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b0f'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '48'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b10'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '47'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b11'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '46'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b12'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '45'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b13'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '44'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b14'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '44'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b15'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '44'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b16'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '42'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b17'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '41'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b18'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '40'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b19'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '40'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b1a'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '40'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b1b'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '39'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b1c'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '37'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b1d'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '36'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b1e'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '36'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b1f'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '35'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b20'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '35'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b21'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '35'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b22'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '33'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b23'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '33'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b24'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '32'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b25'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '31'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b26'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '30'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b27'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '30'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b28'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '29'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b29'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '27'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b2a'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '25'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b2b'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '24'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b2c'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '208',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '22'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b2d'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '362'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b2e'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '288'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b2f'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '277'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b30'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '272'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b31'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '242'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b32'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '233'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b33'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '226'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b34'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '223'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b35'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '221'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b36'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '214'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b37'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '210'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b38'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '200'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b39'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '197'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b3a'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '191'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b3b'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '191'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b3c'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '187'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b3d'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '187'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b3e'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '185'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b3f'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '179'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b40'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '178'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b41'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '172'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b42'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '166'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b43'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '164'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b44'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '164'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b45'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '164'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b46'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '163'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b47'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '162'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b48'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '161'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b49'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '161'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b4a'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '161'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b4b'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '159'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b4c'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '152'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b4d'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '152'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b4e'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '148'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b4f'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '147'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b50'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '146'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b51'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '145'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b52'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '145'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b53'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2013',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '144'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b54'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '144'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b55'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '142'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b56'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '137'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b57'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '136'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b58'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '134'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b59'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '134'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b5a'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '133'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b5b'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '133'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b5c'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '132'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b5d'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '131'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b5e'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '130'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b5f'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '129'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b60'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '129'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b61'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '129'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b62'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2017',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '126'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b63'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2016',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '125'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b64'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '125'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b65'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '122'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b66'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2015',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '121'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b67'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '118'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b68'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2018',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '115'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b69'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2014',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '113'},
#  {'_id': ObjectId('5e5dbcdc851d52ef14137b6a'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2019',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '301',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'España',
#   'Total': '111'},
# ...
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2011',
#   'Month': 'Febrero',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '12'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e83'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2008',
#   'Month': 'Noviembre',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '10'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e84'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2009',
#   'Month': 'Abril',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '10'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e85'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2010',
#   'Month': 'Enero',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '10'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e86'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2010',
#   'Month': 'Febrero',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '9'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e87'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2010',
#   'Month': 'Marzo',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '8'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e88'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2010',
#   'Month': 'Septiembre',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '8'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e89'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2009',
#   'Month': 'Agosto',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '7'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e8a'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2009',
#   'Month': 'Enero',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '6'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e8b'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2011',
#   'Month': 'Enero',
#   'Brand': 'BMW',
#   'Model': '135i_Coupe',
#   'CarType': 'Automoviles',
#   'Segment': 'De_Lujo',
#   'Origin': 'Importado',
#   'OriginCountry': 'Alemania',
#   'Total': '6'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e8c'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '543'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e8d'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '529'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e8e'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '466'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e8f'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '459'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e90'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '453'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e91'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '434'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e92'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '362'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e93'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '351'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e94'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '345'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e95'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '341'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e96'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '326'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e97'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '314'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e98'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '311'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e99'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '303'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e9a'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '288'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e9b'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '281'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e9c'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '275'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e9d'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '273'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e9e'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '270'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137e9f'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '253'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea0'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '235'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea1'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2008',
#   'Month': 'Junio',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '222'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea2'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '220'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea3'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '220'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea4'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2005',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '205'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea5'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2006',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '204'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea6'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '202'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea7'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '183'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea8'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '124'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ea9'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Septiembre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '119'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eaa'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '117'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eab'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Octubre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '114'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eac'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2008',
#   'Month': 'Mayo',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '104'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137ead'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '99'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eae'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2008',
#   'Month': 'Julio',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '97'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eaf'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Diciembre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '96'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eb0'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Agosto',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '94'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eb1'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2008',
#   'Month': 'Marzo',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '90'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eb2'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Febrero',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '88'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eb3'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2008',
#   'Month': 'Enero',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '78'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eb4'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2008',
#   'Month': 'Abril',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '75'},
#  {'_id': ObjectId('5e5dbcdd851d52ef14137eb5'),
#   'TypeOfSale': 'Venta_al_publico_de_vehiculos',
#   'Year': '2007',
#   'Month': 'Noviembre',
#   'Brand': 'Peugeot',
#   'Model': '206_3p',
#   'CarType': 'Automoviles',
#   'Segment': 'Subcompactos',
#   'Origin': 'Importado',
#   'OriginCountry': 'Francia',
#   'Total': '63'},
#  ...]

# %%
salesDF.head()
# Out:
#                       TypeOfSale  Year    Month           Brand Model  \
# 0  Venta_al_publico_de_vehiculos  2005  Febrero  General_Motors   147
# 1  Venta_al_publico_de_vehiculos  2005    Marzo  General_Motors   147
# 2  Venta_al_publico_de_vehiculos  2005     Mayo  General_Motors   147
# 3  Venta_al_publico_de_vehiculos  2005    Enero  General_Motors   147
# 4  Venta_al_publico_de_vehiculos  2005    Abril  General_Motors   147
#
#        CarType  Segment     Origin OriginCountry  Total
# 0  Automoviles  De_Lujo  Importado        Italia     22
# 1  Automoviles  De_Lujo  Importado        Italia     12
# 2  Automoviles  De_Lujo  Importado        Italia     12
# 3  Automoviles  De_Lujo  Importado        Italia     11
# 4  Automoviles  De_Lujo  Importado        Italia     11

# %%
train_size = int(len(salesDF) * 0.9)
test_size = len(salesDF) - train_size
train, test = salesDF.iloc[0:train_size], salesDF.iloc[train_size:len(salesDF)]
print(len(train), len(test))
# Out:
# 59621 6625
